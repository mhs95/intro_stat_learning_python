# %% [markdown]
# # Applied Exercises

# %%
import os

# Set file path
git_path = "/Users/hassansaad/Documents/GitHub"
dir_name = "intro_stat_learning_python"
file_path = os.path.join(git_path, "intro_stat_learning_python", "data")
print(file_path)
# Out:
# /Users/hassansaad/Documents/GitHub/intro_stat_learning_python/data

# %%
# Load data
college = pd.read_csv(f'{file_path}/college.csv')
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
# Set index and remove first column
college = college.set_index(college.iloc[:,0].values)
college = college.iloc[:,1:]
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %% [markdown]
# ### 8c)

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
import seaborn as sns
sns.pairplot(college.iloc[:,0:10])

# %%
import matplotlib.pyplot as plt

fig,axes = plt.subplots(1,1)
sns.boxplot(ax=axes, data = college, y ='Outstate', x ='Private')

# %%
college['Elite'] = "No"
college['Elite'][college['Top10perc']>50] = "Yes"

# %%
college.head(10)
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
# Albertson College                Yes   587     479     158         38
# Albertus Magnus College          Yes   353     340     103         17
# Albion College                   Yes  1899    1720     489         37
# Albright College                 Yes  1038     839     227         30
# Alderson-Broaddus College        Yes   582     498     172         21
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# ...

# %%
college['Elite'].value_counts()
# Out:
# No     699
# Yes     78
# Name: Elite, dtype: int64

# %%
fig,axes = plt.subplots(1,2)
sns.boxplot(ax=axes[0], data = college, y ='Outstate', x ='Private')
sns.boxplot(ax=axes[1], data = college, y ='Outstate', x ='Elite')

# %% [markdown]
# ### 10

# %%
# Load data
auto = pd.read_csv(f'{file_path}/Auto.csv')
auto.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0         130    3504          12.0    70
# 1  15.0          8         350.0         165    3693          11.5    70
# 2  18.0          8         318.0         150    3436          11.0    70
# 3  16.0          8         304.0         150    3433          12.0    70
# 4  17.0          8         302.0         140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
auto.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
qual_vars = ['year','origin', 'name']
quant_vars = ['mpg','cylinders','displacement','horsepower','weight','acceleration']

# %%
for column in auto[quant_vars]:
    var_name = column
    min = np.min(auto[column])
    max = np.max(auto[column])
    range = max-min
    print("Variable : {}, Range: {}".format(column,range))
# Out:
# Variable : mpg, Range: 37.6
# Variable : cylinders, Range: 5
# Variable : displacement, Range: 387.0
# Variable : horsepower, Range: 184
# Variable : weight, Range: 3527
# Variable : acceleration, Range: 16.8

# %%
for column in auto[quant_vars]:
    var_name = column
    mean = np.mean(auto[column])
    std = np.std(auto[column])
    print("Variable : {}, Mean: {}, Std: {}".format(column,mean,std))
# Out:
# Variable : mpg, Mean: 23.44591836734694, Std: 7.795045762682584
# Variable : cylinders, Mean: 5.471938775510204, Std: 1.703606114150195
# Variable : displacement, Mean: 194.41198979591837, Std: 104.51044418133284
# Variable : horsepower, Mean: 104.46938775510205, Std: 38.442032714425984
# Variable : weight, Mean: 2977.5841836734694, Std: 848.3184465698364
# Variable : acceleration, Mean: 15.541326530612228, Std: 2.7553429127509963

# %%
auto_trim = auto.drop(auto.index[9:86])

# %%
for column in auto_trim[quant_vars]:
    var_name = column
    mean = np.mean(auto_trim[column])
    std = np.std(auto_trim[column])
    print("Variable : {}, Mean: {}, Std: {}".format(column,mean,std))
# Out:
# Variable : mpg, Mean: 24.437460317460314, Std: 7.845341954013824
# Variable : cylinders, Mean: 5.365079365079365, Std: 1.6475242349696357
# Variable : displacement, Mean: 186.86984126984126, Std: 99.46034806133925
# Variable : horsepower, Mean: 100.56507936507937, Std: 35.600401989571665
# Variable : weight, Mean: 2933.6349206349205, Std: 810.2362403211521
# Variable : acceleration, Mean: 15.74031746031746, Std: 2.683138394725604

# %%
sns.pairplot(auto.loc[:,quant_vars])

# %% [markdown]
# ### 10

# %%
# Load data
boston = pd.read_csv(f'{file_path}/Boston.csv')
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
np.shape(boston)
# Out:
# (506, 14)

# %%
sns.pairplot(boston)

# %%
for column in boston: 
        var_name = column
        mean = np.mean(boston[column])
        std = np.std(boston[column])
        min = np.min(boston[column])
        max = np.max(boston[column])
        range = max-min
        print("Variable : {}, Mean: {}, Std: {}, Range: {}".format(column,mean,std,range))
# Out:
# Variable : crim, Mean: 3.6135235573122535, Std: 8.593041351295769, Range: 88.96988
# Variable : zn, Mean: 11.363636363636363, Std: 23.299395694766027, Range: 100.0
# Variable : indus, Mean: 11.136778656126504, Std: 6.853570583390873, Range: 27.279999999999998
# Variable : chas, Mean: 0.0691699604743083, Std: 0.25374293496034855, Range: 1
# Variable : nox, Mean: 0.5546950592885372, Std: 0.11576311540656155, Range: 0.486
# Variable : rm, Mean: 6.284634387351788, Std: 0.7019225143345689, Range: 5.218999999999999
# Variable : age, Mean: 68.57490118577078, Std: 28.121032570236885, Range: 97.1
# Variable : dis, Mean: 3.795042687747034, Std: 2.103628356344459, Range: 10.9969
# Variable : rad, Mean: 9.549407114624506, Std: 8.698651117790645, Range: 23
# Variable : tax, Mean: 408.2371541501976, Std: 168.3704950393814, Range: 524
# Variable : ptratio, Mean: 18.455533596837967, Std: 2.162805191482142, Range: 9.4
# ...

# %%
np.median(boston['ptratio'])
# Out:
# 19.05

# %%
print(boston[boston['medv'] == boston['medv'].min()])
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio   black  lstat  medv
# 398     20.2  396.90  30.59   5.0
# 405     20.2  384.97  22.98   5.0

# %%
boston['more_7_rooms'] = "No"
boston['more_7_rooms'][boston['rm']>7] = "Yes" 
boston['more_7_rooms'].value_counts()
# Out:
# No     442
# Yes     64
# Name: more_7_rooms, dtype: int64

# %%
test = boston.groupby('more_7_rooms').mean()
test.head()
# Out:
#                   crim         zn      indus      chas       nox        rm  \
# more_7_rooms
# No            3.994977   8.929864  11.913054  0.061086  0.561970  6.098505
# Yes           0.979109  28.171875   5.775625  0.125000  0.504455  7.570094
#
#                     age       dis        rad         tax    ptratio  \
# more_7_rooms
# No            69.723756  3.736462  10.065611  422.138009  18.773529
# Yes           60.640625  4.199617   5.984375  312.234375  16.259375
#
#                    black      lstat       medv
# more_7_rooms
# No            352.098303  13.692557  20.235747
# Yes           388.275156   5.474063  38.396875

# %%
boston['more_8_rooms'] = "No"
boston['more_8_rooms'][boston['rm']>8] = "Yes" 
boston['more_8_rooms'].value_counts()
# Out:
# No     493
# Yes     13
# Name: more_8_rooms, dtype: int64

# %%
test = boston.groupby('more_8_rooms').mean()
test.head()
# Out:
#                   crim         zn      indus      chas       nox        rm  \
# more_8_rooms
# No            3.689855  11.304260  11.243793  0.066937  0.555103  6.230211
# Yes           0.718795  13.615385   7.078462  0.153846  0.539238  8.348538
#
#                     age       dis       rad         tax    ptratio  \
# more_8_rooms
# No            68.496755  3.804663  9.604462  410.430020  18.510751
# Yes           71.538462  3.430192  7.461538  325.076923  16.361538
#
#                    black      lstat      medv
# more_8_rooms
# No            355.921542  12.873063  21.96146
# Yes           385.210769   4.310000  44.20000
